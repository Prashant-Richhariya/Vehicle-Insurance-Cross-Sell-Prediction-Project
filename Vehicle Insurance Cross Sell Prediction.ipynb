# %% [markdown]
# # Problem Statement

# %% [markdown]
# Our client is an Insurance company that has provided Health Insurance to its customers now they need your help in building a model to predict whether the policyholders (customers) from past year will also be interested in Vehicle Insurance provided by the company.
#
# An insurance policy is an arrangement by which a company undertakes to provide a guarantee of compensation for specified loss, damage, illness, or death in return for the payment of a specified premium. A premium is a sum of money that the customer needs to pay regularly to an insurance company for this guarantee.
#
# For example, you may pay a premium of Rs. 5000 each year for a health insurance cover of Rs. 200,000/- so that if, God forbid, you fall ill and need to be hospitalised in that year, the insurance provider company will bear the cost of hospitalisation etc. for upto Rs. 200,000. Now if you are wondering how can company bear such high hospitalisation cost when it charges a premium of only Rs. 5000/-, that is where the concept of probabilities comes in picture. For example, like you, there may be 100 customers who would be paying a premium of Rs. 5000 every year, but only a few of them (say 2-3) would get hospitalised that year and not everyone. This way everyone shares the risk of everyone else.
#
# Just like medical insurance, there is vehicle insurance where every year customer needs to pay a premium of certain amount to insurance provider company so that in case of unfortunate accident by the vehicle, the insurance provider company will provide a compensation (called ‘sum assured’) to the customer.
#
#  Building a model to predict whether a customer would be interested in Vehicle Insurance is extremely helpful for the company because it can then accordingly plan its communication strategy to reach out to those customers and optimise its business model and revenue.
#
# Now, in order to predict, whether the customer would be interested in Vehicle insurance, you have information about demographics (gender, age, region code type), Vehicles (Vehicle Age, Damage), Policy (Premium, sourcing channel) etc.

# %% [markdown]
# # Attribute Information

# %% [markdown]
# id : Unique ID for the customer
#
# Gender : Gender of the customer
#
# Age : Age of the customer
#
# Driving_License 0 : Customer does not have DL, 1 : Customer already has DL
#
# Region_Code : Unique code for the region of the customer
#
# Previously_Insured : 1 : Customer already has Vehicle Insurance, 0 : Customer doesn't have Vehicle Insurance
#
# Vehicle_Age : Age of the Vehicle
#
# Vehicle_Damage :1 : Customer got his/her vehicle damaged in the past. 0 : Customer didn't get his/her vehicle damaged in the past.
#
# Annual_Premium : The amount customer needs to pay as premium in the year
#
# PolicySalesChannel : Anonymized Code for the channel of outreaching to the customer ie. Different Agents, Over Mail, Over Phone, In Person, etc.
#
# Vintage : Number of Days, Customer has been associated with the company
#
# Response : 1 : Customer is interested, 0 : Customer is not interested

# %%
# Importing libraries for data handling
import pandas as pd
import numpy as np

# Importing libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# To avoid the warning that aren't necessarily exceptions
import warnings
warnings.filterwarnings('ignore')

# Feature Engineering libraries
from sklearn.model_selection import train_test_split 
from collections import Counter
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# Model Selection and Metrics libraries
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.metrics import precision_score,recall_score,accuracy_score,f1_score,confusion_matrix,roc_auc_score,classification_report
from sklearn.metrics import confusion_matrix,classification_report,plot_confusion_matrix
from sklearn.metrics import plot_precision_recall_curve,plot_roc_curve

# %% [markdown]
# # Import Data

# %%
# Loading of data
Health_df = pd.read_csv(r"C:\Users\Prashant Richhariya\Downloads\TRAIN_HEALTH_INSURANCE_CROSS_SELL_PREDICTION.csv")

# %% [markdown]
# # Data Summary

# %%
# Showing first 5 rows of our dataframe
Health_df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1           28                   0
# 1   2    Male   76                1            3                   0
# 2   3    Male   47                1           28                   0
# 3   4    Male   21                1           11                   1
# 4   5  Female   29                1           41                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes           40454                    26      217
# 1    1-2 Year             No           33536                    26      183
# 2   > 2 Years            Yes           38294                    26       27
# 3    < 1 Year             No           28619                   152      203
# 4    < 1 Year             No           27496                   152       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# Showing last 5 rows of our dataframe
Health_df.tail()
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 381104  381105    Male   74                1           26                   1
# 381105  381106    Male   30                1           37                   1
# 381106  381107    Male   21                1           30                   1
# 381107  381108  Female   68                1           14                   0
# 381108  381109    Male   46                1           29                   0
#
#        Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 381104    1-2 Year             No           30170                    26
# 381105    < 1 Year             No           40016                   152
# 381106    < 1 Year             No           35118                   160
# 381107   > 2 Years            Yes           44617                   124
# 381108    1-2 Year             No           41777                    26
#
#         Vintage  Response
# 381104       88         0
# 381105      131         0
# 381106      161         0
# 381107       74         0
# 381108      237         0

# %%
# Finding the size of the dataset
Health_df.shape
# Out:
# (381109, 12)

# %%
# Check for null value and datatype of each column/Feature
Health_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  int64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  int64
#  9   Policy_Sales_Channel  381109 non-null  int64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: int64(9), object(3)
# memory usage: 34.9+ MB

# %% [markdown]
# ### As per above observation we can say that : Dataset consists of 381109 rows & 12 columns. There are no Null or missing values present in the dataset.

# %%
# Descriptive Statistical Summary of Numeric Variables
Health_df.describe()
# Out:
#                   id            Age  Driving_License    Region_Code  \
# count  381109.000000  381109.000000    381109.000000  381109.000000
# mean   190555.000000      38.822584         0.997869      26.388807
# std    110016.836208      15.511611         0.046110      13.229888
# min         1.000000      20.000000         0.000000       0.000000
# 25%     95278.000000      25.000000         1.000000      15.000000
# 50%    190555.000000      36.000000         1.000000      28.000000
# 75%    285832.000000      49.000000         1.000000      35.000000
# max    381109.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel  \
# count       381109.000000   381109.000000         381109.000000
# mean             0.458210    30564.389581            112.034295
# std              0.498251    17213.155057             54.203995
# min              0.000000     2630.000000              1.000000
# 25%              0.000000    24405.000000             29.000000
# 50%              0.000000    31669.000000            133.000000
# 75%              1.000000    39400.000000            152.000000
# max              1.000000   540165.000000            163.000000
#
#              Vintage       Response
# count  381109.000000  381109.000000
# mean      154.347397       0.122563
# std        83.671304       0.327936
# min        10.000000       0.000000
# 25%        82.000000       0.000000
# 50%       154.000000       0.000000
# 75%       227.000000       0.000000
# max       299.000000       1.000000

# %%
# Checking unique values of each features
Health_df.nunique()
# Out:
# id                      381109
# Gender                       2
# Age                         66
# Driving_License              2
# Region_Code                 53
# Previously_Insured           2
# Vehicle_Age                  3
# Vehicle_Damage               2
# Annual_Premium           48838
# Policy_Sales_Channel       155
# Vintage                    290
# Response                     2
# dtype: int64

# %%
# Checking for duplicates
Health_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### No duplicate value present in our dataset

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
#  Exploratory Data Analysis refers to the critical process of performing initial investigations on data so as to discover patterns,to spot anomalies,to test hypothesis and to check assumptions with the help of summary statistics and graphical representations

# %%
#Here, in our target variable(Response) 0 means the customer was not intrested in vechicle insurance and 1 means the customer was intrested in vehicle insurance. 

fig, axes = plt.subplots(ncols=2,figsize=(20,5))
sns.countplot(Health_df['Response'], data=Health_df,ax = axes[0],palette = 'BuGn_r')
plt.title('Not-Interested vs Interested Policyholders', fontsize=13) #title for the countplot
colors = ['#4F6272', '#B7C3F3', '#DD7596', '#8EB897']
Health_df['Response'].value_counts().plot.pie( autopct = '%.1f%%',ax = axes[1],explode = [0.02,0.02],colors = colors, figsize=(15,7))
plt.show()

# %% [markdown]
# ### The given dataset is an imbalance problem as the Response variable with the value 1 is significantly lower than the value zero

# %% [markdown]
# # Gender

# %%
# # Analyzing Gender feature and it's effect on response feature
fig, axes = plt.subplots(ncols=2,figsize=(20,5))
colors = ['#4F6272', '#B7C3F3', '#DD7596', '#8EB897']
Health_df['Gender'].value_counts().plot.pie( autopct = '%.1f%%',ax = axes[0],explode = [0.02,0.02],colors=colors, figsize=(15,7))
ax = sns.countplot(data = Health_df , x = 'Response', ax = axes[1],palette = 'BuGn_r', hue = 'Gender',)

# %% [markdown]
# ### From below plots we can see number of men is bit more than women, so we have a little gender-gap  here.
# ### Male category is somewhat more noteworthy than that of female and chances of purchasing the insurance is likewise minimal high
# ### Males seems to have more interest in vehicle insurance than women so we have to target woman more to increase conversion rate of women for vehicle insurance

# %% [markdown]
# # Age

# %%
# Analysis of Age distribution
plt.figure(figsize=(25,7))
sns.countplot(Health_df['Age'],palette = 'RdYlBu')
plt.title("AGE-DISTRIBUTION")
plt.show()

# %%
# Analysis of Age & Response
plt.figure(figsize=(25,7))
ax = sns.countplot(data = Health_df , x = 'Age', palette = 'BuPu', hue = 'Response',)

# %% [markdown]
# ### Youngsters under 30 are not intrigued by vehicle insurance. Reasons could be absence of involvement, less awareness about insurance and they may not have costly vehicles yet.

# %% [markdown]
# ### People of age range between 30-60 years are more likely to be interested and willing to purchase

# %% [markdown]
# # Region code

# %%
# Analyzing region feature 
plt.figure(figsize=(25,7))
sns.countplot(Health_df['Region_Code'],palette = 'RdYlBu')
plt.title("REGION-DISTRIBUTION")
plt.show()

# %%
# Analyzing region feature and it's effect on response feature
plt.figure(figsize=(25,7))
ax = sns.countplot(data = Health_df , x = 'Region_Code', palette = 'BuPu', hue = 'Response',)

# %% [markdown]
# ### Area code 28 has the most health insurance clients and region code 51 has the fewest

# %% [markdown]
# # Driving_License

# %%
# Analyzing Driving_License feature and it's effect on response feature
fig, axes = plt.subplots(ncols=2,figsize=(20,5))
colors = ['#4F6272', '#B7C3F3']
Health_df['Driving_License'].value_counts().plot.pie( autopct = '%.1f%%',ax = axes[0],explode = [0.02,0.02],colors=colors, figsize=(15,7))
ax = sns.countplot(data = Health_df , x = 'Response', ax = axes[1],palette = 'BuGn_r', hue = 'Driving_License',)

# %% [markdown]
# ### We can see that if there is a license holder than it will be more likely to buy an insurance.
# ### Also there is very less count of People who do not have driving license.

# %% [markdown]
# # Previously_Insured

# %%
# Analyzing Previously_Insured feature and it's effect on response feature
fig, axes = plt.subplots(ncols=2,figsize=(20,5))
colors = ['#4F6272', '#B7C3F3', '#DD7596', '#8EB897']
Health_df['Previously_Insured'].value_counts().plot.pie( autopct = '%.1f%%',ax = axes[0],explode = [0.02,0.02],colors=colors, figsize=(15,7))
ax = sns.countplot(data = Health_df , x = 'Response', ax = axes[1],palette = 'BuGn_r', hue = 'Previously_Insured',)

# %% [markdown]
# ### More than 50% of people doesn't have insurance.
# ### It seems that customer those who already had vehicle insurance tends to have less interest  in having another vehicle insurance

# %% [markdown]
# # Vehicle Age

# %%
# Analyzing Vehicle Age feature and it's effect on response feature
fig, axes = plt.subplots(ncols=2,figsize=(20,5))
colors = ['#4F6272', '#B7C3F3', '#DD7596', '#8EB897']
Health_df['Vehicle_Age'].value_counts().plot.pie( autopct = '%.1f%%',ax = axes[0],explode = [0.02,0.02,0.02],colors=colors, figsize=(15,7))
ax = sns.countplot(data = Health_df , x = 'Response', ax = axes[1],palette = 'BuGn_r', hue = 'Vehicle_Age',)

# %% [markdown]
# ### Consumers with 1-2-year-old vehicles are more interested as compared to others.
# ### Consumers with less than 1 year old Vehicles have very less chance of buying Insurance

# %% [markdown]
# # Vehicle_Damage

# %%
# Analyzing Vehicle_Damage feature and it's effect on response feature
fig, axes = plt.subplots(ncols=2,figsize=(20,5))
colors = ['#4F6272', '#B7C3F3', '#DD7596', '#8EB897']
Health_df['Vehicle_Damage'].value_counts().plot.pie( autopct = '%.1f%%',ax = axes[0],explode = [0.02,0.02],colors=colors, figsize=(15,7))
ax = sns.countplot(data = Health_df , x = 'Response', ax = axes[1],palette = 'BuGn_r', hue = 'Vehicle_Damage',)

# %% [markdown]
# ### We can see from below graph that customer interested in vehicle insurance are mostly  those who had their vehicle damaged in past.
# ### Half of all health insurance customers have had their car destroyed, while the other half have not

# %% [markdown]
# # Annual_Premium

# %%
# Analysis on Annual distribution along with response relation with annual premium

# defining figures
fig, axes = plt.subplots(2,1, figsize =( 25,12))

# plotting distplot for annual premium
sns.distplot( x= Health_df['Annual_Premium'], ax = axes[0],color= "#bcbddc",bins = 100)
axes[0].set_title('Annual premium distribution')

# plotting hist plot and response distribution 
sns.histplot( x= Health_df['Annual_Premium'], ax = axes[1], bins = 200,color="#bcbddc", kde = True)
sns.histplot( x= Health_df['Annual_Premium'][Health_df['Response'] == 1], ax = axes[1], bins = 200, color = '#756bb1', kde = True)
axes[1].set_title('Annual premium vs response')
# Out:
# Text(0.5, 1.0, 'Annual premium vs response')

# %% [markdown]
# ### Its observed from the distribution plot, that the annual premimum feature is right skewed

# %% [markdown]
# # Vintage

# %%
# Plotting the distplot for vintange 
fig= plt.subplots(figsize = (10,6))
sns.distplot( x= Health_df['Vintage'], color= '#2E8B57')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Analyzing Vintage feature and it's effect on response feature
fig= plt.subplots(figsize = (20,6))
sns.histplot( x= Health_df['Vintage'],color="#bcbddc", kde = True)
sns.histplot( x= Health_df['Vintage'][Health_df['Response'] == 1], color = '#756bb1', kde = True)
axes[1].set_title(' Vintage vs response')
# Out:
# Text(0.5, 1.0, ' Vintage vs response')

# %% [markdown]
# ### Vintage - Number of Days, Customer has been associated with the company.
# ### There seems to be no such relation between vintage and response.

# %% [markdown]
# # Multivariate Analysis

# %%
# Plotting heatmap to find correlation
plt.figure(figsize=(18,9))
ax = sns.heatmap(Health_df.corr(),annot=True)

# %% [markdown]
# ### There is no such strong correlation among features as we can see from the above heatmap.

# %% [markdown]
# # Checking for Outliers

# %%
#Checking for outliers 
int_df = Health_df[list(Health_df.describe())]

for column in int_df:
    plt.figure(figsize=( 5,2))
    sns.boxplot(data=int_df,x=column)

# %% [markdown]
# ### Annual_premium feature contains outliers so we will tranfrom Annual_premium to normal distribution

# %% [markdown]
# ### Since we have outliers in annual_premium and the data is also right skewed, we apply power  Transform to Annual_premium

# %% [markdown]
# # Powertransform in Machine Learning
#
#  Power transforms are a family of parametric, monotonic transformations that are applied to make data more Gaussian-like. This is useful for modeling issues related to heteroscedasticity (non-constant variance), or other situations where normality is desired.
#  Currently, PowerTransformer supports the Box-Cox transform and the Yeo-Johnson transform. The optimal parameter for stabilizing variance and minimizing skewness is estimated through maximum likelihood.
# •	Box-Cox requires input data to be strictly positive,
# •	while Yeo-Johnson supports both positive or negative data.
# •	By default, zero-mean, unit-variance normalization is applied to the transformed data.

# %%
features = Health_df[['Annual_Premium']]

# %%
#instatiate 
from sklearn.preprocessing import PowerTransformer

pt = PowerTransformer(method='yeo-johnson', standardize=True,) 

#Fitting data to the powertransformer
skl_yeojohnson = pt.fit(features)

#Lets get the Lambdas that were found
print (skl_yeojohnson.lambdas_)

calc_lambdas = skl_yeojohnson.lambdas_

#Transform the data 
skl_yeojohnson = pt.transform(features)

#Pass the transformed data into a new dataframe 
Health_df['Annual_Premium'] = pd.DataFrame(data=skl_yeojohnson, columns=['Annual_Premium'])

Health_df['Annual_Premium']
# Out:
# [0.76692882]
# 0         0.612207
# 1         0.243028
# 2         0.498644
# 3        -0.030214
# 4        -0.094107
#             ...
# 381104    0.057079
# 381105    0.589296
# 381106    0.328903
# 381107    0.827191
# 381108    0.681065
# Name: Annual_Premium, Length: 381109, dtype: float64

# %%
fig= plt.subplots(figsize = (10,6))
sns.distplot( x= Health_df['Annual_Premium'], color= 'g')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### We will drop id column as it has not attribute

# %%
# Droping id column
Health_df.drop("id",inplace=True,axis=1)

# %% [markdown]
# # Encoding

# %%
#encoding numerical columns to categorcial 
#we will use both label as well as one hot encoding for transformation of data type
le = LabelEncoder()
ohe = OneHotEncoder()

#mapping
Health_df["Vehicle_Age"]=Health_df["Vehicle_Age"].map({"> 2 Years":2,"1-2 Year":1,"< 1 Year":0})


#categorical to numerical
Health_df['Gender'] = ohe.fit_transform(Health_df[["Gender"]]).toarray()
Health_df['Vehicle_Age'] = le.fit_transform(Health_df[['Vehicle_Age']])
Health_df['Vehicle_Damage'] = le.fit_transform(Health_df[['Vehicle_Damage']])

# %%
# Showing first 5 rows of our dataframe
Health_df.head()
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured  Vehicle_Age  \
# 0     0.0   44                1           28                   0            2
# 1     0.0   76                1            3                   0            1
# 2     0.0   47                1           28                   0            2
# 3     0.0   21                1           11                   1            0
# 4     1.0   29                1           41                   1            0
#
#    Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0               1        0.612207                    26      217         1
# 1               0        0.243028                    26      183         0
# 2               1        0.498644                    26       27         1
# 3               0       -0.030214                   152      203         0
# 4               0       -0.094107                   152       39         0

# %%
# Check for null value and datatype of each column/Feature
Health_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Gender                381109 non-null  float64
#  1   Age                   381109 non-null  int64
#  2   Driving_License       381109 non-null  int64
#  3   Region_Code           381109 non-null  int64
#  4   Previously_Insured    381109 non-null  int64
#  5   Vehicle_Age           381109 non-null  int64
#  6   Vehicle_Damage        381109 non-null  int32
#  7   Annual_Premium        381109 non-null  float64
#  8   Policy_Sales_Channel  381109 non-null  int64
#  9   Vintage               381109 non-null  int64
#  10  Response              381109 non-null  int64
# dtypes: float64(2), int32(1), int64(8)
# memory usage: 30.5 MB

# %% [markdown]
# # Feature selection

# %%
# Importing important libraries
from statsmodels.stats.outliers_influence import variance_inflation_factor
# Function to Calculate VIF
def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
# VIF values for independent features
calc_vif(Health_df[[i for i in Health_df.describe().columns if i not in ['Response']]])
# Out:
#               variables        VIF
# 0                Gender   1.900420
# 1                   Age  18.381724
# 2       Driving_License  40.268862
# 3           Region_Code   4.957160
# 4    Previously_Insured   5.724299
# 5           Vehicle_Age   6.034246
# 6        Vehicle_Damage   6.351624
# 7        Annual_Premium   1.014392
# 8  Policy_Sales_Channel   8.107759
# 9               Vintage   4.373705

# %%
# Droping Driving_License variable
Health_df= Health_df.drop(["Driving_License"],axis=1)

# %%
# VIF values for independent features
calc_vif(Health_df[[i for i in Health_df.describe().columns if i not in ['Response']]])
# Out:
#               variables        VIF
# 0                Gender   1.847842
# 1                   Age  13.471196
# 2           Region_Code   4.558850
# 3    Previously_Insured   4.620188
# 4           Vehicle_Age   6.023186
# 5        Vehicle_Damage   5.186692
# 6        Annual_Premium   1.013756
# 7  Policy_Sales_Channel   5.217964
# 8               Vintage   4.066432

# %% [markdown]
# ### After dropping Driving_License we got good VIF scores

# %% [markdown]
# ## Handling Imbalance using SMOTE(Synthetic Minority Oversampling Technique)
# SMOTE  Synthetic Minority Oversampling Technique or SMOTE is another technique to oversample the minority class. Simply adding duplicate records of minority class often don’t add any new information to the model. In SMOTE new instances are synthesized from the existing data. If we explain it in simple words, SMOTE looks into minority class instances and use k nearest neighbor to select a random nearest neighbor, and a synthetic instance is created randomly in feature space.

# %%
X=Health_df.drop(['Response'],axis=1) #contain all  independent variable
y=Health_df['Response']           #dependent variable

# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\prashant richhariya\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\prashant richhariya\anaconda3\lib\site-packages (from imblearn) (0.10.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\prashant richhariya\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\prashant richhariya\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\prashant richhariya\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.9.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\prashant richhariya\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.23.5)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\prashant richhariya\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.2.0)

# %%
# Importing libraries for resampling
# Handling imbalance data
from imblearn.over_sampling import SMOTE

smote = SMOTE()

# fit predictor and target variable
X, y = smote.fit_resample(X, y)


print('Original dataset shape', len(Health_df))
print('Resampled dataset shape', len(y))
# Out:
# Original dataset shape 381109
# Resampled dataset shape 668798

# %%
X.shape
# Out:
# (668798, 9)

# %% [markdown]
# # Test-Train Split

# %%
# Splitting the dataset into training and testing
X_train,X_test,y_train,y_test = train_test_split(X, y,test_size=0.20,random_state = 10)

# %%
# Checking balanced data for train dataset
y_train.value_counts()
# Out:
# 1    267521
# 0    267517
# Name: Response, dtype: int64

# %%
# Checking balanced data for test dataset
y_test.value_counts()
# Out:
# 0    66882
# 1    66878
# Name: Response, dtype: int64

# %% [markdown]
# # Model

# %% [markdown]
# # Logistic Regression
#  Logistic regression is a classification algorithm that predicts the probability of an outcome that can only have two values (i.e. a dichotomy). A logistic regression produces a logistic curve, which is limited to values between 0 and 1. Logistic regression models the probability that each input belongs to a particular category.
#   Logistic regression is used to describe data and to explain the relationship between one dependent binary variable and one or more nominal, ordinal, interval or ratio-level independent variables

# %%
# Model of logistic regression
LOG_RE=LogisticRegression()
LOG_RE=LOG_RE.fit(X_train,y_train)
LOG_RE_pred=LOG_RE.predict(X_test)
LOG_RE_probability =LOG_RE.predict_proba(X_test)[:,1]

# evaluating the model on the following metrics.
accu_logreg = accuracy_score(y_test,LOG_RE_pred)
recall_logreg = recall_score(y_test,LOG_RE_pred)
prec_logreg = precision_score(y_test,LOG_RE_pred)
f1score_logreg=f1_score(y_test,LOG_RE_pred)
roc_auc= roc_auc_score(y_test,LOG_RE_probability)

#print accuracy ,classification report and confusion matrix  values of model.
print("Accuracy: ",accu_logreg *100)
print("Recall: ",round(recall_logreg,3))
print("Precision: ",round(prec_logreg,3))
print("F1 score: ",round(f1score_logreg,3))
print("ROC AUC score: ",round(roc_auc,3))

print(classification_report(y_test,LOG_RE_pred))

matrix = confusion_matrix(y_test,LOG_RE_pred)
print('Confusion matrix : \n',matrix)
# Out:
# Accuracy:  77.74671052631578
# Recall:  0.964
# Precision:  0.702
# F1 score:  0.812
# ROC AUC score:  0.814
#               precision    recall  f1-score   support
#
#            0       0.94      0.59      0.73     66882
#            1       0.70      0.96      0.81     66878
#
#     accuracy                           0.78    133760
#    macro avg       0.82      0.78      0.77    133760
# weighted avg       0.82      0.78      0.77    133760
#
# Confusion matrix :
#  [[39538 27344]
#  [ 2422 64456]]

# %%
# Importing roc curve
# The ROC curve is created by plotting the true positive rate (TPR) against the false positive rate (FPR) at various threshold settings.
from sklearn.metrics import roc_curve
fpr, tpr, _ = roc_curve(y_test,LOG_RE_probability)

# Evaluation metrics
plt.title('logistic Regression ROC curve')
plt.xlabel('FPR (Precision)')
plt.ylabel('TPR (Recall)')

# Performance metrics
plt.plot(fpr,tpr)
plt.plot((0,1), ls='dashed',color='black')
plt.show()

# %%
# Confusion matrix 
cm=confusion_matrix(y_test,LOG_RE_pred)
print(cm)
sns.heatmap(cm,annot=True,cmap='BuPu')
# Out:
# [[39538 27344]
#  [ 2422 64456]]
# <AxesSubplot:>

# %% [markdown]
# # Decision Tree

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Creating instance for our model, fiting and predicitng
dtree = DecisionTreeClassifier()
dtree = dtree.fit(X_train, y_train)
dtree_pred = dtree.predict(X_test)
dtree_probability =dtree.predict_proba(X_test)[:,1]

# evaluating the model on the following metrics.
accu_dtree = accuracy_score(y_test,dtree_pred)
recall_dtree = recall_score(y_test,dtree_pred)
prec_dtree = precision_score(y_test,dtree_pred)
f1score_dtree=f1_score(y_test,dtree_pred)
roc_auc_dtree = roc_auc_score(y_test,dtree_probability)
#print accuracy ,classification report and confusion matrix  values of model.

print("Accuracy: ",accu_dtree*100)
print("Recall: ",round(recall_dtree,3))
print("Precision: ",round(prec_dtree,3))
print("F1 score: ",round(f1score_dtree,3))
print("ROC AUC Score: ",round(roc_auc_dtree,3))

print(classification_report(y_test, dtree_pred))

print('Confusion matrix : \n',confusion_matrix(y_test,dtree_pred, labels=[1,0]))
# Out:
# Accuracy:  85.96740430622009
# Recall:  0.876
# Precision:  0.848
# F1 score:  0.862
# ROC AUC Score:  0.86
#               precision    recall  f1-score   support
#
#            0       0.87      0.84      0.86     66882
#            1       0.85      0.88      0.86     66878
#
#     accuracy                           0.86    133760
#    macro avg       0.86      0.86      0.86    133760
# weighted avg       0.86      0.86      0.86    133760
#
# Confusion matrix :
#  [[58581  8297]
#  [10473 56409]]

# %%
# Analyze Performance 
from sklearn.metrics import roc_curve
fpr, tpr, _ = roc_curve(y_test,dtree_probability)

plt.title('Decision Tree ROC curve')
plt.xlabel('FPR (Precision)')
plt.ylabel('TPR (Recall)')

plt.plot(fpr,tpr)
plt.plot((0,1), ls='dashed',color='black')
plt.show()

# %%
# Confusion matrix useful to find how many values are classified correctly
cm=confusion_matrix(y_test,dtree_pred)
print(cm)
sns.heatmap(cm,annot=True,cmap='BuPu')
# Out:
# [[56409 10473]
#  [ 8297 58581]]
# <AxesSubplot:>

# %% [markdown]
# # Random Forest classifier

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Creating instance for our model, fiting and predicitng
rf_tree = RandomForestClassifier()
rf_tree.fit(X_train, y_train)
rf_tree_pred = rf_tree.predict(X_test)
rf_tree_probability = rf_tree.predict_proba(X_test)[:,1]

# evaluating the model on the following metrics.
accu_rf= accuracy_score(y_test,rf_tree_pred)
recall_rf = recall_score(y_test,rf_tree_pred)
prec_rf= precision_score(y_test,rf_tree_pred)
f1score_rf=f1_score(y_test,rf_tree_pred)
roc_auc_rf=roc_auc_score(y_test,rf_tree_probability)

#print accuracy ,classification report and confusion matrix  values of model.

print("Accuracy: ",accu_rf*100)
print("Recall: ",round(recall_rf,3))
print("Precision: ",round(prec_rf,3))
print("F1 score: ",round(f1score_rf,3))
print("Roc Auc score: ",round(roc_auc_rf,3))
print(classification_report(y_test, rf_tree_pred))
print("Confusion matrix\n", confusion_matrix(y_test, rf_tree_pred))
# Out:
# Accuracy:  88.90774521531101
# Recall:  0.922
# Precision:  0.865
# F1 score:  0.893
# Roc Auc score:  0.965
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89     66882
#            1       0.87      0.92      0.89     66878
#
#     accuracy                           0.89    133760
#    macro avg       0.89      0.89      0.89    133760
# weighted avg       0.89      0.89      0.89    133760
#
# Confusion matrix
#  [[57289  9593]
#  [ 5244 61634]]

# %%
# Analyze Performance 
from sklearn.metrics import roc_curve
fpr, tpr, _ = roc_curve(y_test,rf_tree_probability )

plt.title('RandomForestClassifier ROC curve')
plt.xlabel('FPR (Precision)')
plt.ylabel('TPR (Recall)')

plt.plot(fpr,tpr)
plt.plot((0,1), ls='dashed',color='black')
plt.show()

# %%
# Confusion matrix useful to find how many values are classified correctly
cm=confusion_matrix(y_test,rf_tree_pred)
print(cm)
sns.heatmap(cm,annot=True,cmap='BuPu')
# Out:
# [[57289  9593]
#  [ 5244 61634]]
# <AxesSubplot:>

# %% [markdown]
# # XGBoost Classifier
#  XGBoost is an optimized distributed gradient boosting library designed for efficient and scalable training of machine learning models. It is an ensemble learning method that combines the predictions of multiple weak models to produce a stronger prediction. XGBoost stands for “Extreme Gradient Boosting” and it has become one of the most popular and widely used machine learning algorithms due to its ability to handle large datasets and its ability to achieve state-of-the-art performance in many machine learning tasks such as classification and regression.

# %%
# Importing of XGBClassifier
import xgboost as xgb
xgb_model=xgb.XGBClassifier()
xgb_model.fit(X_train,y_train)
xgb_pred = xgb_model.predict(X_test)
xgb_model_probability = xgb_model.predict_proba(X_test)[:,1]

# evaluating the model on the following metrics.
accu_xgb = accuracy_score(y_test,xgb_pred)
recall_xgb = recall_score(y_test,xgb_pred)
prec_xgb = precision_score(y_test,xgb_pred)
f1score_xgb=f1_score(y_test,xgb_pred)
roc_auc_xgb = roc_auc_score(y_test,xgb_model_probability )
print("ROC AUC Score:",round(roc_auc,2))

#print accuracy ,classification report and confusion matrix  values of model.

print("Accuracy: ",accu_xgb*100)
print("Recall: ",round(recall_xgb,3))
print("Precision: ",round(prec_xgb,3))
print("F1 score: ",round(f1score_xgb,3))
print("Roc Auc score: ",round(roc_auc_xgb,3))


print(classification_report(y_test, xgb_pred))
print("Confusion matrix\n", confusion_matrix(y_test, xgb_pred))
# Out:
# [22:02:41] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ROC AUC Score: 0.81
# Accuracy:  84.65161483253588
# Recall:  0.895
# Precision:  0.816
# F1 score:  0.854
# Roc Auc score:  0.936
#               precision    recall  f1-score   support
#
#            0       0.88      0.80      0.84     66882
#            1       0.82      0.89      0.85     66878
#
#     accuracy                           0.85    133760
#    macro avg       0.85      0.85      0.85    133760
# weighted avg       0.85      0.85      0.85    133760
#
# Confusion matrix
#  [[53381 13501]
#  [ 7029 59849]]

# %%
# performance and evaluation
from sklearn.metrics import roc_curve
fpr, tpr, _ = roc_curve(y_test,xgb_model_probability)

plt.title('XGB Classifier curve')
plt.xlabel('FPR (Precision)')
plt.ylabel('TPR (Recall)')

plt.plot(fpr,tpr)
plt.plot((0,1), ls='dashed',color='black')
plt.show()

# %%
# Confusion matrix useful to find how many values are classified correctly
cm=confusion_matrix(y_test,xgb_pred)
print(cm)
sns.heatmap(cm,annot=True,cmap='BuPu')
# Out:
# [[53381 13501]
#  [ 7029 59849]]
# <AxesSubplot:>

# %% [markdown]
# # Comparing Models

# %%
## Comparing the performance of the models
ind=['Logistic regression','Decision Tree','Randomforest','XGBClassifier']
df={"Accuracy":[accu_logreg,accu_dtree,accu_rf,accu_xgb],"Recall":[recall_logreg,recall_dtree,recall_rf,recall_xgb],"Precision":[prec_logreg,prec_dtree,prec_rf,prec_xgb],'f1_score':[f1score_logreg,f1score_dtree,f1score_rf,f1score_xgb]}
result=pd.DataFrame(data=df,index=ind)
result
# Out:
#                      Accuracy    Recall  Precision  f1_score
# Logistic regression  0.777467  0.963785   0.702135  0.812413
# Decision Tree        0.859674  0.875938   0.848336  0.861916
# Randomforest         0.889077  0.921589   0.865318  0.892567
# XGBClassifier        0.846516  0.894898   0.815937  0.853596

# %% [markdown]
# ### After comparing the values of accuracy,recall,precision, F1 score, Roc Auc score , we can see that Random Forest model performs better than all of the other models.
# ### After that in descending order of performance – Decision Tree, Xgboost and Logistic Regression model perform better.

# %% [markdown]
# # **Hyperparameter tuning**

# %%
# installing the important libraries
# !pip install scikit-optimize
# Out:
# Requirement already satisfied: scikit-optimize in c:\users\prashant richhariya\anaconda3\lib\site-packages (0.10.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\prashant richhariya\anaconda3\lib\site-packages (from scikit-optimize) (21.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\prashant richhariya\anaconda3\lib\site-packages (from scikit-optimize) (1.2.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\prashant richhariya\anaconda3\lib\site-packages (from scikit-optimize) (1.0.2)
# Requirement already satisfied: pyaml>=16.9 in c:\users\prashant richhariya\anaconda3\lib\site-packages (from scikit-optimize) (26.2.1)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\prashant richhariya\anaconda3\lib\site-packages (from scikit-optimize) (1.23.5)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\prashant richhariya\anaconda3\lib\site-packages (from scikit-optimize) (1.9.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\prashant richhariya\anaconda3\lib\site-packages (from packaging>=21.3->scikit-optimize) (3.0.9)
# Requirement already satisfied: PyYAML in c:\users\prashant richhariya\anaconda3\lib\site-packages (from pyaml>=16.9->scikit-optimize) (6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\prashant richhariya\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->scikit-optimize) (2.2.0)

# %%
# Importing Bayes search CV for hyperparameter tuning
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer

# %%
# #Hyperparameter Tuning on RandomForestClassifier

rf = RandomForestClassifier(random_state=40)
#Cross validation and hyperparameter tuning
rf_bayes = BayesSearchCV(estimator= rf,
                         search_spaces = {
                          'max_depth': Integer(2,100),
                          'min_samples_leaf': Integer(1,100),
                          'min_samples_split': Integer(2,100),
                          'n_estimators': Integer(1,140),
                          'max_features': ["auto", "sqrt", "log2"]
                        },
                       cv = 5, verbose=2, scoring='accuracy',n_iter=10)

rf_bayes.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=94, min_samples_split=62, n_estimators=63; total time=  30.6s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=94, min_samples_split=62, n_estimators=63; total time=  27.9s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=94, min_samples_split=62, n_estimators=63; total time=  28.3s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=94, min_samples_split=62, n_estimators=63; total time=  28.1s
# [CV] END max_depth=21, max_features=sqrt, min_samples_leaf=94, min_samples_split=62, n_estimators=63; total time=  28.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END max_depth=41, max_features=sqrt, min_samples_leaf=63, min_samples_split=73, n_estimators=68; total time=  32.5s
# [CV] END max_depth=41, max_features=sqrt, min_samples_leaf=63, min_samples_split=73, n_estimators=68; total time=  32.2s
# [CV] END max_depth=41, max_features=sqrt, min_samples_leaf=63, min_samples_split=73, n_estimators=68; total time=  37.0s
# [CV] END max_depth=41, max_features=sqrt, min_samples_leaf=63, min_samples_split=73, n_estimators=68; total time=  36.2s
# [CV] END max_depth=41, max_features=sqrt, min_samples_leaf=63, min_samples_split=73, n_estimators=68; total time=  32.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END max_depth=3, max_features=auto, min_samples_leaf=63, min_samples_split=38, n_estimators=37; total time=   5.6s
# [CV] END max_depth=3, max_features=auto, min_samples_leaf=63, min_samples_split=38, n_estimators=37; total time=   5.8s
# [CV] END max_depth=3, max_features=auto, min_samples_leaf=63, min_samples_split=38, n_estimators=37; total time=   6.0s
# [CV] END max_depth=3, max_features=auto, min_samples_leaf=63, min_samples_split=38, n_estimators=37; total time=   5.8s
# [CV] END max_depth=3, max_features=auto, min_samples_leaf=63, min_samples_split=38, n_estimators=37; total time=   6.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END max_depth=29, max_features=log2, min_samples_leaf=50, min_samples_split=95, n_estimators=97; total time=  47.4s
# [CV] END max_depth=29, max_features=log2, min_samples_leaf=50, min_samples_split=95, n_estimators=97; total time=  53.4s
# [CV] END max_depth=29, max_features=log2, min_samples_leaf=50, min_samples_split=95, n_estimators=97; total time= 1.1min
# [CV] END max_depth=29, max_features=log2, min_samples_leaf=50, min_samples_split=95, n_estimators=97; total time=  59.3s
# [CV] END max_depth=29, max_features=log2, min_samples_leaf=50, min_samples_split=95, n_estimators=97; total time=  49.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END max_depth=41, max_features=sqrt, min_samples_leaf=82, min_samples_split=50, n_estimators=106; total time=  53.9s
# [CV] END max_depth=41, max_features=sqrt, min_samples_leaf=82, min_samples_split=50, n_estimators=106; total time=  54.9s
# [CV] END max_depth=41, max_features=sqrt, min_samples_leaf=82, min_samples_split=50, n_estimators=106; total time=  50.3s
# [CV] END max_depth=41, max_features=sqrt, min_samples_leaf=82, min_samples_split=50, n_estimators=106; total time=  48.8s
# [CV] END max_depth=41, max_features=sqrt, min_samples_leaf=82, min_samples_split=50, n_estimators=106; total time=  48.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END max_depth=45, max_features=log2, min_samples_leaf=71, min_samples_split=56, n_estimators=11; total time=   5.4s
# [CV] END max_depth=45, max_features=log2, min_samples_leaf=71, min_samples_split=56, n_estimators=11; total time=   5.3s
# [CV] END max_depth=45, max_features=log2, min_samples_leaf=71, min_samples_split=56, n_estimators=11; total time=   5.3s
# [CV] END max_depth=45, max_features=log2, min_samples_leaf=71, min_samples_split=56, n_estimators=11; total time=   5.6s
# [CV] END max_depth=45, max_features=log2, min_samples_leaf=71, min_samples_split=56, n_estimators=11; total time=   5.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END max_depth=42, max_features=sqrt, min_samples_leaf=64, min_samples_split=18, n_estimators=137; total time= 1.2min
# [CV] END max_depth=42, max_features=sqrt, min_samples_leaf=64, min_samples_split=18, n_estimators=137; total time= 1.1min
# [CV] END max_depth=42, max_features=sqrt, min_samples_leaf=64, min_samples_split=18, n_estimators=137; total time= 1.1min
# [CV] END max_depth=42, max_features=sqrt, min_samples_leaf=64, min_samples_split=18, n_estimators=137; total time= 1.1min
# [CV] END max_depth=42, max_features=sqrt, min_samples_leaf=64, min_samples_split=18, n_estimators=137; total time= 1.2min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END max_depth=70, max_features=auto, min_samples_leaf=77, min_samples_split=65, n_estimators=81; total time=  46.3s
# [CV] END max_depth=70, max_features=auto, min_samples_leaf=77, min_samples_split=65, n_estimators=81; total time=  47.6s
# [CV] END max_depth=70, max_features=auto, min_samples_leaf=77, min_samples_split=65, n_estimators=81; total time=  45.1s
# [CV] END max_depth=70, max_features=auto, min_samples_leaf=77, min_samples_split=65, n_estimators=81; total time=  45.4s
# [CV] END max_depth=70, max_features=auto, min_samples_leaf=77, min_samples_split=65, n_estimators=81; total time=  42.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END max_depth=60, max_features=log2, min_samples_leaf=15, min_samples_split=29, n_estimators=60; total time=  34.7s
# [CV] END max_depth=60, max_features=log2, min_samples_leaf=15, min_samples_split=29, n_estimators=60; total time=  31.8s
# [CV] END max_depth=60, max_features=log2, min_samples_leaf=15, min_samples_split=29, n_estimators=60; total time=  32.4s
# [CV] END max_depth=60, max_features=log2, min_samples_leaf=15, min_samples_split=29, n_estimators=60; total time=  32.6s
# [CV] END max_depth=60, max_features=log2, min_samples_leaf=15, min_samples_split=29, n_estimators=60; total time=  31.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END max_depth=55, max_features=log2, min_samples_leaf=39, min_samples_split=84, n_estimators=112; total time= 1.0min
# [CV] END max_depth=55, max_features=log2, min_samples_leaf=39, min_samples_split=84, n_estimators=112; total time=  56.8s
# [CV] END max_depth=55, max_features=log2, min_samples_leaf=39, min_samples_split=84, n_estimators=112; total time= 1.1min
# [CV] END max_depth=55, max_features=log2, min_samples_leaf=39, min_samples_split=84, n_estimators=112; total time= 1.0min
# [CV] END max_depth=55, max_features=log2, min_samples_leaf=39, min_samples_split=84, n_estimators=112; total time=  58.5s
# BayesSearchCV(cv=5, estimator=RandomForestClassifier(random_state=40),
#               n_iter=10, scoring='accuracy',
#               search_spaces={'max_depth': Integer(low=2, high=100, prior='uniform', transform='normalize'),
#                              'max_features': ['auto', 'sqrt', 'log2'],
#                              'min_samples_leaf': Integer(low=1, high=100, prior='uniform', transform='normalize'),
#                              'min_samples_split': Integer(low=2, high=100, prior='uniform', transform='normalize'),
#                              'n_estimators': Integer(low=1, high=140, prior='uniform', transform='normalize')},
#               verbose=2)

# %%
rf_bayes.best_params_
# Out:
# OrderedDict([('max_depth', 60),
#              ('max_features', 'log2'),
#              ('min_samples_leaf', 15),
#              ('min_samples_split', 29),
#              ('n_estimators', 60)])

# %%
rf_bayes.best_estimator_
# Out:
# RandomForestClassifier(max_depth=60, max_features='log2', min_samples_leaf=15,
#                        min_samples_split=29, n_estimators=60, random_state=40)

# %%
rf_bayestest_pred=rf_bayes.best_estimator_.predict(X_test)

# %%
rf_model_probability = rf_bayes.best_estimator_.predict_proba(X_test)[:,1]

# %%
# evaluating the model on the following metrics.
accu_rf_hp = accuracy_score(y_test,rf_bayestest_pred)
recall_rf_hp = recall_score(y_test,rf_bayestest_pred)
prec_rf_hp = precision_score(y_test,rf_bayestest_pred)
f1score_rf_hp=f1_score(y_test,rf_bayestest_pred)

#print accuracy ,classification report and confusion matrix  values of model.

print(accuracy_score(y_test, rf_bayestest_pred)*100)
print(classification_report(y_test, rf_bayestest_pred))
print("Confusion matrix\n", confusion_matrix(y_test, rf_bayestest_pred))
# Out:
# 85.68256578947368
#               precision    recall  f1-score   support
#
#            0       0.89      0.81      0.85     66882
#            1       0.83      0.90      0.86     66878
#
#     accuracy                           0.86    133760
#    macro avg       0.86      0.86      0.86    133760
# weighted avg       0.86      0.86      0.86    133760
#
# Confusion matrix
#  [[54174 12708]
#  [ 6443 60435]]

# %%
# performance and evaluation
from sklearn.metrics import roc_curve
fpr, tpr, _ = roc_curve(y_test,rf_model_probability)

plt.title('RandomForestClassifier')
plt.xlabel('FPR (Precision)')
plt.ylabel('TPR (Recall)')

plt.plot(fpr,tpr)
plt.plot((0,1), ls='dashed',color='black')
plt.show()

# %%
# Confusion matrix useful to find how many values are classified correctly
cm=confusion_matrix(y_test,rf_bayestest_pred)
print(cm)
sns.heatmap(cm,annot=True,cmap='BuPu')
# Out:
# [[54174 12708]
#  [ 6443 60435]]
# <AxesSubplot:>

# %% [markdown]
# ### XGBoostClassifier

# %%
import xgboost as xgb
from skopt import BayesSearchCV
from skopt.space import Integer, Real, Categorical

# 1. Initialize the model with the explicit evaluation metric to silence warnings
xgb_model = xgb.XGBClassifier(eval_metric='logloss', use_label_encoder=False)

# 2. Cross-validation and hyperparameter tuning with proper XGBoost spaces
xgb_bayes = BayesSearchCV(
    estimator=xgb_model,
    search_spaces={
        'max_depth': Integer(2, 50),                 # Tree depth (reduced 100 to 50 to prevent overfitting/slow training)
        'min_child_weight': Integer(1, 20),          # Replaces min_samples_leaf
        'gamma': Real(0, 10, prior='uniform'),       # Replaces min_samples_split (controls minimum loss reduction)
        'n_estimators': Integer(10, 150),            # Number of boosting rounds
        'colsample_bytree': Real(0.5, 1.0, prior='uniform') # Replaces max_features (percentage of features per tree)
    },
    cv=5, 
    verbose=2, 
    scoring='accuracy',
    n_iter=4,
    random_state=42
)

# 3. Fit the model
xgb_bayes.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.705051979426657, gamma=7.277257431773251, max_depth=47, min_child_weight=7, n_estimators=104; total time= 1.4min
# [CV] END colsample_bytree=0.705051979426657, gamma=7.277257431773251, max_depth=47, min_child_weight=7, n_estimators=104; total time= 1.4min
# [CV] END colsample_bytree=0.705051979426657, gamma=7.277257431773251, max_depth=47, min_child_weight=7, n_estimators=104; total time= 1.2min
# [CV] END colsample_bytree=0.705051979426657, gamma=7.277257431773251, max_depth=47, min_child_weight=7, n_estimators=104; total time= 1.3min
# [CV] END colsample_bytree=0.705051979426657, gamma=7.277257431773251, max_depth=47, min_child_weight=7, n_estimators=104; total time= 1.3min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9186941777766422, gamma=8.833152773808623, max_depth=17, min_child_weight=19, n_estimators=131; total time=  44.7s
# [CV] END colsample_bytree=0.9186941777766422, gamma=8.833152773808623, max_depth=17, min_child_weight=19, n_estimators=131; total time=  47.2s
# [CV] END colsample_bytree=0.9186941777766422, gamma=8.833152773808623, max_depth=17, min_child_weight=19, n_estimators=131; total time=  44.5s
# [CV] END colsample_bytree=0.9186941777766422, gamma=8.833152773808623, max_depth=17, min_child_weight=19, n_estimators=131; total time=  40.6s
# [CV] END colsample_bytree=0.9186941777766422, gamma=8.833152773808623, max_depth=17, min_child_weight=19, n_estimators=131; total time=  39.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.7224162561505759, gamma=9.18722521669377, max_depth=7, min_child_weight=9, n_estimators=36; total time=   3.8s
# [CV] END colsample_bytree=0.7224162561505759, gamma=9.18722521669377, max_depth=7, min_child_weight=9, n_estimators=36; total time=   4.0s
# [CV] END colsample_bytree=0.7224162561505759, gamma=9.18722521669377, max_depth=7, min_child_weight=9, n_estimators=36; total time=   4.0s
# [CV] END colsample_bytree=0.7224162561505759, gamma=9.18722521669377, max_depth=7, min_child_weight=9, n_estimators=36; total time=   3.8s
# [CV] END colsample_bytree=0.7224162561505759, gamma=9.18722521669377, max_depth=7, min_child_weight=9, n_estimators=36; total time=   4.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END colsample_bytree=0.9061979941786817, gamma=1.718715613965607, max_depth=31, min_child_weight=16, n_estimators=83; total time=  43.6s
# [CV] END colsample_bytree=0.9061979941786817, gamma=1.718715613965607, max_depth=31, min_child_weight=16, n_estimators=83; total time=  43.3s
# [CV] END colsample_bytree=0.9061979941786817, gamma=1.718715613965607, max_depth=31, min_child_weight=16, n_estimators=83; total time=  43.7s
# [CV] END colsample_bytree=0.9061979941786817, gamma=1.718715613965607, max_depth=31, min_child_weight=16, n_estimators=83; total time=  43.5s
# [CV] END colsample_bytree=0.9061979941786817, gamma=1.718715613965607, max_depth=31, min_child_weight=16, n_estimators=83; total time=  49.2s
# BayesSearchCV(cv=5,
#               estimator=XGBClassifier(base_score=None, booster=None,
#                                       colsample_bylevel=None,
#                                       colsample_bynode=None,
#                                       colsample_bytree=None,
#                                       enable_categorical=False,
#                                       eval_metric='logloss', gamma=None,
#                                       gpu_id=None, importance_type=None,
#                                       interaction_constraints=None,
#                                       learning_rate=None, max_delta_step=None,
#                                       max_depth=None, min_child_weight=None,
#                                       missing=nan, mon...
#               search_spaces={'colsample_bytree': Real(low=0.5, high=1.0, prior='uniform', transform='normalize'),
#                              'gamma': Real(low=0, high=10, prior='uniform', transform='normalize'),
#                              'max_depth': Integer(low=2, high=50, prior='uniform', transform='normalize'),
#                              'min_child_weight': Integer(low=1, high=20, prior='uniform', transform='normalize'),
#                              'n_estimators': Integer(low=10, high=150, prior='uniform', transform='normalize')},
#               verbose=2)

# %%
xgb_bayes.best_params_
# Out:
# OrderedDict([('colsample_bytree', 0.9061979941786817),
#              ('gamma', 1.718715613965607),
#              ('max_depth', 31),
#              ('min_child_weight', 16),
#              ('n_estimators', 83)])

# %%
xgb_bayes.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.9061979941786817,
#               enable_categorical=False, eval_metric='logloss',
#               gamma=1.718715613965607, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=31, min_child_weight=16, missing=nan,
#               monotone_constraints='()', n_estimators=83, n_jobs=12,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %%
xgbtest_pred=xgb_bayes.best_estimator_.predict(X_test)

# %%
xgb_model_probability = rf_bayes.best_estimator_.predict_proba(X_test)[:,1]

# %%
# evaluating the model on the following metrics.
accu_xgb_hp = accuracy_score(y_test,xgbtest_pred)
recall_xgb_hp= recall_score(y_test,xgbtest_pred)
prec_xgb_hp = precision_score(y_test,xgbtest_pred)
f1score_xgb_hp=f1_score(y_test,xgbtest_pred)

#print accuracy ,classification report and confusion matrix  values of model.

print(accuracy_score(y_test, xgbtest_pred)*100)
print(classification_report(y_test, xgbtest_pred))
print("Confusion matrix\n", confusion_matrix(y_test, xgbtest_pred))
# Out:
# 87.1867523923445
#               precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87     66882
#            1       0.85      0.91      0.88     66878
#
#     accuracy                           0.87    133760
#    macro avg       0.87      0.87      0.87    133760
# weighted avg       0.87      0.87      0.87    133760
#
# Confusion matrix
#  [[55992 10890]
#  [ 6249 60629]]

# %%
# performance and evaluation
from sklearn.metrics import roc_curve
fpr, tpr, _ = roc_curve(y_test,xgb_model_probability)

plt.title('XGB Classifier curve')
plt.xlabel('FPR (Precision)')
plt.ylabel('TPR (Recall)')

plt.plot(fpr,tpr)
plt.plot((0,1), ls='dashed',color='black')
plt.show()

# %%
# Confusion matrix useful to find how many values are classified correctly
cm=confusion_matrix(y_test,xgbtest_pred)
print(cm)
sns.heatmap(cm,annot=True,cmap='BuPu')
# Out:
# [[55992 10890]
#  [ 6249 60629]]
# <AxesSubplot:>

# %% [markdown]
# **Comparing The Model After Hyperparameter Tuning**

# %%
## Comparing the performance of the models
ind=['Randomforest','XGBClassifier']
df={"Accuracy":[accu_rf_hp,accu_xgb_hp],"Recall":[recall_rf_hp,recall_xgb_hp],"Precision":[prec_rf_hp,prec_xgb_hp],'f1_score':[f1score_rf_hp,f1score_xgb_hp]}
result=pd.DataFrame(data=df,index=ind)
result
# Out:
#                Accuracy    Recall  Precision  f1_score
# Randomforest   0.856826  0.903660   0.826258  0.863228
# XGBClassifier  0.871868  0.906561   0.847733  0.876161
